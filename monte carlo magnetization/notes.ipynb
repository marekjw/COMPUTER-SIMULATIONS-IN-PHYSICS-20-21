# %%
from main import run_simulation
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# # Zadanie 1

# %%
temperatures = [1, 2, 3, 4, 5]
L = 5
t_steps = 1000
m_steps = 5000

[(run_simulation(L, t_steps, m_steps, t), t) for t in temperatures]
# Out:
# [(0.997791999999974, 1),
#  (0.9195839999999993, 2),
#  (0.4765759999999945, 3),
#  (0.3591840000000224, 4),
#  (0.29377600000003345, 5)]

# %% [markdown]
# # Zadanie 2

# %%
temperatures = np.linspace(1, 5, 100)
t_steps = m_steps = 1500

res10 = [run_simulation(10, t_steps, m_steps, t) for t in temperatures]
res20 = [run_simulation(20, t_steps, m_steps, t) for t in temperatures]

# %%
plt.plot(temperatures, res10, label='L = 10')
plt.plot(temperatures, res20, label='L = 20')

xs = np.linspace(1, 4, 1000)
plt.plot(
    xs, 
    (1-1/np.sinh(2/xs*1)**4)**(1/8)
)

plt.legend()

# %%
(1-1/np.sinh(0.882)**4)**(1/8)
# Out:
# 0.4938230032352283
